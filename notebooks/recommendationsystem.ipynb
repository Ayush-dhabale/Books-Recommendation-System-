# %% [markdown]
# # **Recommendation System**

# %% [markdown]
# ## **Collaborative Filtering**

# %% [markdown]
# ## **Objective**
# The goal is to develop a **book recommendation system** that suggests books to users based on their past interactions.
# We will use **collaborative filtering**, which finds patterns in user-book interactions to provide personalized recommendations.
#
# ## **Criteria for Users and Books**
# To ensure meaningful recommendations, we apply the following filtering criteria:
# 1. **Users Selection**
#    - Consider **only users who have rated at least 200 books**.
#    - This ensures that recommendations are based on users with enough reading history.
#
# 2. **Books Selection**
#    - Include **only books that have received at least 50 ratings**.
#    - This ensures that the books considered are popular enough to have reliable ratings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy import stats

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv("../artifacts/cleaned_data.csv",encoding='ISO-8859-1')
book_df = pd.read_csv('data/Books.csv',encoding='ISO-8859-1')

# %%
data
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# 4        The Amsterdam Connection : Level 4 (Cambridge ...        Sue Leather
# ...                                                    ...                ...
# 1031131  Edgar Cayce on the Akashic Records: The Book o...  Kevin J. Todeschi
# 1031132  Get Clark Smart : The Ultimate Guide for the S...       Clark Howard
# 1031133  Eight Weeks to Optimum Health: A Proven Progra...        Andrew Weil
# 1031134   The Sherbrooke Bride (Bride Trilogy (Paperback))  Catherine Coulter
# 1031135                                  Fourth Grade Rats     Jerry Spinelli
#
#          Year-Of-Publication  \
# 0                     2002.0
# 1                     2001.0
# 2                     1996.0
# 3                     1999.0
# 4                     2001.0
# ...                      ...
# 1031131               1998.0
# 1031132               2000.0
# 1031133               1997.0
# 1031134               1996.0
# 1031135               1996.0
#
#                                                  Publisher   Age        City  \
# 0                                         Ballantine Books  35.0       tyler
# 1                                                   Heinle  35.0     seattle
# 2                                             Warner Books  16.0           h
# 3                               Cambridge University Press  16.0      rijeka
# 4                               Cambridge University Press  16.0      rijeka
# ...                                                    ...   ...         ...
# 1031131  A.R.E. Press (Association of Research &amp; Enlig  35.0  cedar park
# 1031132                                   Longstreet Press  36.0  cedar park
# 1031133                                    Alfred A. Knopf  18.0      quebec
# 1031134                                         Jove Books  38.0  mannington
# 1031135                                         Scholastic  14.0  providence
#
#                    State    Country     Age Group
# 0                  texas        usa  Young Adults
# 1             washington        usa  Young Adults
# 2        new south wales  australia         Teens
# 3                    NaN    croatia         Teens
# 4                    NaN    croatia         Teens
# ...                  ...        ...           ...
# 1031131            texas        usa  Young Adults
# 1031132            texas        usa   Middle-aged
# 1031133           quebec     canada         Teens
# 1031134    west virginia        usa   Middle-aged
# 1031135     rhode island        usa         Teens
#
# [1031136 rows x 12 columns]

# %%
data = data.merge(book_df, on= 'ISBN')

# %%
data
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                               Book-Title_x      Book-Author_x  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# 4        The Amsterdam Connection : Level 4 (Cambridge ...        Sue Leather
# ...                                                    ...                ...
# 1031131  Edgar Cayce on the Akashic Records: The Book o...  Kevin J. Todeschi
# 1031132  Get Clark Smart : The Ultimate Guide for the S...       Clark Howard
# 1031133  Eight Weeks to Optimum Health: A Proven Progra...        Andrew Weil
# 1031134   The Sherbrooke Bride (Bride Trilogy (Paperback))  Catherine Coulter
# 1031135                                  Fourth Grade Rats     Jerry Spinelli
#
#          Year-Of-Publication_x  \
# 0                       2002.0
# 1                       2001.0
# 2                       1996.0
# 3                       1999.0
# 4                       2001.0
# ...                        ...
# 1031131                 1998.0
# 1031132                 2000.0
# 1031133                 1997.0
# 1031134                 1996.0
# 1031135                 1996.0
#
#                                                Publisher_x   Age        City  \
# 0                                         Ballantine Books  35.0       tyler
# 1                                                   Heinle  35.0     seattle
# 2                                             Warner Books  16.0           h
# 3                               Cambridge University Press  16.0      rijeka
# 4                               Cambridge University Press  16.0      rijeka
# ...                                                    ...   ...         ...
# 1031131  A.R.E. Press (Association of Research &amp; Enlig  35.0  cedar park
# 1031132                                   Longstreet Press  36.0  cedar park
# 1031133                                    Alfred A. Knopf  18.0      quebec
# 1031134                                         Jove Books  38.0  mannington
# 1031135                                         Scholastic  14.0  providence
#
#                    State    Country     Age Group  \
# 0                  texas        usa  Young Adults
# 1             washington        usa  Young Adults
# 2        new south wales  australia         Teens
# 3                    NaN    croatia         Teens
# 4                    NaN    croatia         Teens
# ...                  ...        ...           ...
# 1031131            texas        usa  Young Adults
# 1031132            texas        usa   Middle-aged
# 1031133           quebec     canada         Teens
# 1031134    west virginia        usa   Middle-aged
# 1031135     rhode island        usa         Teens
#
#                                               Book-Title_y      Book-Author_y  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# 4        The Amsterdam Connection : Level 4 (Cambridge ...        Sue Leather
# ...                                                    ...                ...
# 1031131  Edgar Cayce on the Akashic Records: The Book o...  Kevin J. Todeschi
# 1031132  Get Clark Smart : The Ultimate Guide for the S...       Clark Howard
# 1031133  Eight Weeks to Optimum Health: A Proven Progra...        Andrew Weil
# 1031134   The Sherbrooke Bride (Bride Trilogy (Paperback))  Catherine Coulter
# 1031135                                  Fourth Grade Rats     Jerry Spinelli
#
#         Year-Of-Publication_y  \
# 0                        2002
# 1                        2001
# 2                        1996
# 3                        1999
# 4                        2001
# ...                       ...
# 1031131                  1998
# 1031132                  2000
# 1031133                  1997
# 1031134                  1996
# 1031135                  1996
#
#                                                Publisher_y  \
# 0                                         Ballantine Books
# 1                                                   Heinle
# 2                                             Warner Books
# 3                               Cambridge University Press
# 4                               Cambridge University Press
# ...                                                    ...
# 1031131  A.R.E. Press (Association of Research &amp; Enlig
# 1031132                                   Longstreet Press
# 1031133                                    Alfred A. Knopf
# 1031134                                         Jove Books
# 1031135                                         Scholastic
#
#                                                Image-URL-S  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
#                                                Image-URL-M  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
#                                                Image-URL-L
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
# [1031136 rows x 19 columns]

# %% [markdown]
# ### **Grouping the user with book ratings count**

# %%
data.groupby('User-ID')['Book-Rating'].count().reset_index()
# Out:
#        User-ID  Book-Rating
# 0            2            1
# 1            8           17
# 2            9            3
# 3           10            1
# 4           12            1
# ...        ...          ...
# 92101   278846            1
# 92102   278849            4
# 92103   278851           23
# 92104   278852            1
# 92105   278854            8
#
# [92106 rows x 2 columns]

# %% [markdown]
# - Only 92k out of total user have rated the books
# - Majority of the user haven't rated the books

# %% [markdown]
# ### **Flitering the data where user have rated more than equal to 200 books**

# %%
users_with_200_ratings_data = data.loc[data.groupby('User-ID')['Book-Rating'].transform('count') >= 200]

# %%
users_with_200_ratings_data
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1151      277427  0026217457            0
# 1152      277427  003008685X            8
# 1153      277427  0030615321            0
# 1154      277427  0060002050            0
# ...          ...         ...          ...
# 1029357   275970  1931868123            0
# 1029358   275970  3411086211           10
# 1029359   275970  3829021860            0
# 1029360   275970  4770019572            0
# 1029361   275970  9626340762            8
#
#                                               Book-Title_x  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1151                    Vegetarian Times Complete Cookbook
# 1152                                              Pioneers
# 1153      Ask for May, Settle for June (A Doonesbury book)
# 1154                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# 1029357  There's a Porcupine in My Outhouse: Misadventu...
# 1029358                                         Die Biene.
# 1029359                                     The Penis Book
# 1029360                                            Musashi
# 1029361  Northanger Abbey (Classic Literature with Clas...
#
#                                Book-Author_x  Year-Of-Publication_x  \
# 1150                       James Finn Garner                 1994.0
# 1151                              Lucy  Moll                 1995.0
# 1152                   James Fenimore Cooper                 1974.0
# 1153                           G. B. Trudeau                 1982.0
# 1154                       Stephanie Laurens                 2002.0
# ...                                      ...                    ...
# 1029357                         Mike Tougias                 2002.0
# 1029358  Sybil GrÃ?ÃÂ¤fin SchÃ?ÃÂ¶nfeldt                 1993.0
# 1029359                         Joseph Cohen                 1999.0
# 1029360                       Eiji Yoshikawa                 1995.0
# 1029361                          Jane Austen                 1996.0
#
#                                   Publisher_x   Age        City         State  \
# 1150                John Wiley &amp; Sons Inc  48.0     gilbert       arizona
# 1151                    John Wiley &amp; Sons  48.0     gilbert       arizona
# 1152                         Thomson Learning  48.0     gilbert       arizona
# 1153                      Henry Holt &amp; Co  48.0     gilbert       arizona
# 1154                               Avon Books  48.0     gilbert       arizona
# ...                                       ...   ...         ...           ...
# 1029357                    Capital Books (VA)  46.0  pittsburgh  pennsylvania
# 1029358  Bibliographisches Institut, Mannheim  46.0  pittsburgh  pennsylvania
# 1029359                              Konemann  46.0  pittsburgh  pennsylvania
# 1029360          Kodansha International (JPN)  46.0  pittsburgh  pennsylvania
# 1029361                 Naxos Audiobooks Ltd.  46.0  pittsburgh  pennsylvania
#
#         Country    Age Group  \
# 1150        usa  Middle-aged
# 1151        usa  Middle-aged
# 1152        usa  Middle-aged
# 1153        usa  Middle-aged
# 1154        usa  Middle-aged
# ...         ...          ...
# 1029357     usa  Middle-aged
# 1029358     usa  Middle-aged
# 1029359     usa  Middle-aged
# 1029360     usa  Middle-aged
# 1029361     usa  Middle-aged
#
#                                               Book-Title_y  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1151                    Vegetarian Times Complete Cookbook
# 1152                                              Pioneers
# 1153      Ask for May, Settle for June (A Doonesbury book)
# 1154                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# 1029357  There's a Porcupine in My Outhouse: Misadventu...
# 1029358                                         Die Biene.
# 1029359                                     The Penis Book
# 1029360                                            Musashi
# 1029361  Northanger Abbey (Classic Literature with Clas...
#
#                          Book-Author_y Year-Of-Publication_y  \
# 1150                 James Finn Garner                  1994
# 1151                        Lucy  Moll                  1995
# 1152             James Fenimore Cooper                  1974
# 1153                     G. B. Trudeau                  1982
# 1154                 Stephanie Laurens                  2002
# ...                                ...                   ...
# 1029357                   Mike Tougias                  2002
# 1029358  Sybil GrÃ?Â¤fin SchÃ?Â¶nfeldt                  1993
# 1029359                   Joseph Cohen                  1999
# 1029360                 Eiji Yoshikawa                  1995
# 1029361                    Jane Austen                  1996
#
#                                   Publisher_y  \
# 1150                John Wiley &amp; Sons Inc
# 1151                    John Wiley &amp; Sons
# 1152                         Thomson Learning
# 1153                      Henry Holt &amp; Co
# 1154                               Avon Books
# ...                                       ...
# 1029357                    Capital Books (VA)
# 1029358  Bibliographisches Institut, Mannheim
# 1029359                              Konemann
# 1029360          Kodansha International (JPN)
# 1029361                 Naxos Audiobooks Ltd.
#
#                                                Image-URL-S  \
# 1150     http://images.amazon.com/images/P/002542730X.0...
# 1151     http://images.amazon.com/images/P/0026217457.0...
# 1152     http://images.amazon.com/images/P/003008685X.0...
# 1153     http://images.amazon.com/images/P/0030615321.0...
# 1154     http://images.amazon.com/images/P/0060002050.0...
# ...                                                    ...
# 1029357  http://images.amazon.com/images/P/1931868123.0...
# 1029358  http://images.amazon.com/images/P/3411086211.0...
# 1029359  http://images.amazon.com/images/P/3829021860.0...
# 1029360  http://images.amazon.com/images/P/4770019572.0...
# 1029361  http://images.amazon.com/images/P/9626340762.0...
#
#                                                Image-URL-M  \
# 1150     http://images.amazon.com/images/P/002542730X.0...
# 1151     http://images.amazon.com/images/P/0026217457.0...
# 1152     http://images.amazon.com/images/P/003008685X.0...
# 1153     http://images.amazon.com/images/P/0030615321.0...
# 1154     http://images.amazon.com/images/P/0060002050.0...
# ...                                                    ...
# 1029357  http://images.amazon.com/images/P/1931868123.0...
# 1029358  http://images.amazon.com/images/P/3411086211.0...
# 1029359  http://images.amazon.com/images/P/3829021860.0...
# 1029360  http://images.amazon.com/images/P/4770019572.0...
# 1029361  http://images.amazon.com/images/P/9626340762.0...
#
#                                                Image-URL-L
# 1150     http://images.amazon.com/images/P/002542730X.0...
# 1151     http://images.amazon.com/images/P/0026217457.0...
# 1152     http://images.amazon.com/images/P/003008685X.0...
# 1153     http://images.amazon.com/images/P/0030615321.0...
# 1154     http://images.amazon.com/images/P/0060002050.0...
# ...                                                    ...
# 1029357  http://images.amazon.com/images/P/1931868123.0...
# 1029358  http://images.amazon.com/images/P/3411086211.0...
# 1029359  http://images.amazon.com/images/P/3829021860.0...
# 1029360  http://images.amazon.com/images/P/4770019572.0...
# 1029361  http://images.amazon.com/images/P/9626340762.0...
#
# [475007 rows x 19 columns]

# %% [markdown]
# - Users with **200+** rating have rated **50%** of the books
#
# ---

# %% [markdown]
# ### **Fliter this filtered data on books with 50+ ratings**

# %%
users_with_200_ratings_data.groupby('Book-Title_x')['Book-Rating_x'].count().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 users_with_200_ratings_data.groupby('Book-Title')['Book-Rating'].count().reset_index()
#
# File c:\Users\adhab\OneDrive\Desktop\Execlr Project\P505\recommendationvevn\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File c:\Users\adhab\OneDrive\Desktop\Execlr Project\P505\recommendationvevn\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\adhab\OneDrive\Desktop\Execlr Project\P505\recommendationvevn\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Book-Title'

# %%
final_filtered_data = users_with_200_ratings_data.loc[users_with_200_ratings_data.groupby('Book-Title')['Book-Rating'].transform('count') >= 50]

# %%
final_filtered_data
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1163      277427  0060930535            0
# 1165      277427  0060934417            0
# 1168      277427  0061009059            9
# 1174      277427  006440188X            0
# ...          ...         ...          ...
# 1029196   275970  1400031354            0
# 1029197   275970  1400031362            0
# 1029270   275970  1573229725            0
# 1029309   275970  1586210661            9
# 1029310   275970  1586212230            0
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1163                         The Poisonwood Bible: A Novel
# 1165                                    Bel Canto: A Novel
# 1168     One for the Money (Stephanie Plum Novels (Pape...
# 1174                                     The Secret Garden
# ...                                                    ...
# 1029196  Tears of the Giraffe (No.1 Ladies Detective Ag...
# 1029197  Morality for Beautiful Girls (No.1 Ladies Dete...
# 1029270                                        Fingersmith
# 1029309                             Me Talk Pretty One Day
# 1029310                                              Naked
#
#                      Book-Author  Year-Of-Publication  \
# 1150           James Finn Garner               1994.0
# 1163          Barbara Kingsolver               1999.0
# 1165                Ann Patchett               2002.0
# 1168             Janet Evanovich               1995.0
# 1174     Frances Hodgson Burnett               1998.0
# ...                          ...                  ...
# 1029196   Alexander McCall Smith               2002.0
# 1029197   Alexander McCall Smith               2002.0
# 1029270             Sarah Waters               2002.0
# 1029309            David Sedaris               2001.0
# 1029310            David Sedaris               2001.0
#
#                          Publisher   Age        City         State Country  \
# 1150     John Wiley &amp; Sons Inc  48.0     gilbert       arizona     usa
# 1163                     Perennial  48.0     gilbert       arizona     usa
# 1165                     Perennial  48.0     gilbert       arizona     usa
# 1168                   HarperTorch  48.0     gilbert       arizona     usa
# 1174                  HarperTrophy  48.0     gilbert       arizona     usa
# ...                            ...   ...         ...           ...     ...
# 1029196                     Anchor  46.0  pittsburgh  pennsylvania     usa
# 1029197                     Anchor  46.0  pittsburgh  pennsylvania     usa
# 1029270            Riverhead Books  46.0  pittsburgh  pennsylvania     usa
# 1029309    Time Warner Audio Major  46.0  pittsburgh  pennsylvania     usa
# 1029310    Time Warner Audio Major  46.0  pittsburgh  pennsylvania     usa
#
#            Age Group
# 1150     Middle-aged
# 1163     Middle-aged
# 1165     Middle-aged
# 1168     Middle-aged
# 1174     Middle-aged
# ...              ...
# 1029196  Middle-aged
# 1029197  Middle-aged
# 1029270  Middle-aged
# 1029309  Middle-aged
# 1029310  Middle-aged
#
# [58823 rows x 12 columns]

# %% [markdown]
# - only **58k** books have ratings more than 50 and rated by top users(**>=200 ratings**)
#
# ---

# %% [markdown]
# # **Creating the User-Book Interaction Matrix for Recommendations**
#
# ## **Why Do We Need This Matrix?**
# To implement **collaborative filtering**, we require a structured representation of user-book interactions.
# A **pivot table** helps us transform raw data into a **User-Book interaction matrix**, where:
# - **Rows represent books (Book-Title).**
# - **Columns represent users (User-ID).**
# - **Values represent ratings given by users to books.**
#
# This matrix allows us to analyze **user behavior patterns** and find similarities between users or books.
#
# ## **Why is This Approach Effective?**
# - The matrix enables **pattern recognition** in user behavior.
# - It allows us to compute **similarities between users or books**.
# - It forms the foundation for **personalized book recommendations**.
#
# 🚀 **This matrix is the backbone of our collaborative filtering-based recommendation system!**

# %% [markdown]
# ### **Pivot Table**

# %%
final_filtered_data
# Out:
#        User-ID        ISBN  Book-Rating  \
# 0       277427  002542730X           10
# 1       277427  0060930535            0
# 2       277427  0060934417            0
# 3       277427  0061009059            9
# 4       277427  006440188X            0
# ...        ...         ...          ...
# 58818   275970  1400031354            0
# 58819   275970  1400031362            0
# 58820   275970  1573229725            0
# 58821   275970  1586210661            9
# 58822   275970  1586212230            0
#
#                                             Book-Title_x  \
# 0      Politically Correct Bedtime Stories: Modern Ta...
# 1                          The Poisonwood Bible: A Novel
# 2                                     Bel Canto: A Novel
# 3      One for the Money (Stephanie Plum Novels (Pape...
# 4                                      The Secret Garden
# ...                                                  ...
# 58818  Tears of the Giraffe (No.1 Ladies Detective Ag...
# 58819  Morality for Beautiful Girls (No.1 Ladies Dete...
# 58820                                        Fingersmith
# 58821                             Me Talk Pretty One Day
# 58822                                              Naked
#
#                  Book-Author_x  Year-Of-Publication_x  \
# 0            James Finn Garner                 1994.0
# 1           Barbara Kingsolver                 1999.0
# 2                 Ann Patchett                 2002.0
# 3              Janet Evanovich                 1995.0
# 4      Frances Hodgson Burnett                 1998.0
# ...                        ...                    ...
# 58818   Alexander McCall Smith                 2002.0
# 58819   Alexander McCall Smith                 2002.0
# 58820             Sarah Waters                 2002.0
# 58821            David Sedaris                 2001.0
# 58822            David Sedaris                 2001.0
#
#                      Publisher_x   Age        City         State Country  \
# 0      John Wiley &amp; Sons Inc  48.0     gilbert       arizona     usa
# 1                      Perennial  48.0     gilbert       arizona     usa
# 2                      Perennial  48.0     gilbert       arizona     usa
# 3                    HarperTorch  48.0     gilbert       arizona     usa
# 4                   HarperTrophy  48.0     gilbert       arizona     usa
# ...                          ...   ...         ...           ...     ...
# 58818                     Anchor  46.0  pittsburgh  pennsylvania     usa
# 58819                     Anchor  46.0  pittsburgh  pennsylvania     usa
# 58820            Riverhead Books  46.0  pittsburgh  pennsylvania     usa
# 58821    Time Warner Audio Major  46.0  pittsburgh  pennsylvania     usa
# 58822    Time Warner Audio Major  46.0  pittsburgh  pennsylvania     usa
#
#          Age Group                                       Book-Title_y  \
# 0      Middle-aged  Politically Correct Bedtime Stories: Modern Ta...
# 1      Middle-aged                      The Poisonwood Bible: A Novel
# 2      Middle-aged                                 Bel Canto: A Novel
# 3      Middle-aged  One for the Money (Stephanie Plum Novels (Pape...
# 4      Middle-aged                                  The Secret Garden
# ...            ...                                                ...
# 58818  Middle-aged  Tears of the Giraffe (No.1 Ladies Detective Ag...
# 58819  Middle-aged  Morality for Beautiful Girls (No.1 Ladies Dete...
# 58820  Middle-aged                                        Fingersmith
# 58821  Middle-aged                             Me Talk Pretty One Day
# 58822  Middle-aged                                              Naked
#
#                  Book-Author_y Year-Of-Publication_y  \
# 0            James Finn Garner                  1994
# 1           Barbara Kingsolver                  1999
# 2                 Ann Patchett                  2002
# 3              Janet Evanovich                  1995
# 4      Frances Hodgson Burnett                  1998
# ...                        ...                   ...
# 58818   Alexander McCall Smith                  2002
# 58819   Alexander McCall Smith                  2002
# 58820             Sarah Waters                  2002
# 58821            David Sedaris                  2001
# 58822            David Sedaris                  2001
#
#                      Publisher_y  \
# 0      John Wiley &amp; Sons Inc
# 1                      Perennial
# 2                      Perennial
# 3                    HarperTorch
# 4                   HarperTrophy
# ...                          ...
# 58818                     Anchor
# 58819                     Anchor
# 58820            Riverhead Books
# 58821    Time Warner Audio Major
# 58822    Time Warner Audio Major
#
#                                              Image-URL-S  \
# 0      http://images.amazon.com/images/P/002542730X.0...
# 1      http://images.amazon.com/images/P/0060930535.0...
# 2      http://images.amazon.com/images/P/0060934417.0...
# 3      http://images.amazon.com/images/P/0061009059.0...
# 4      http://images.amazon.com/images/P/006440188X.0...
# ...                                                  ...
# 58818  http://images.amazon.com/images/P/1400031354.0...
# 58819  http://images.amazon.com/images/P/1400031362.0...
# 58820  http://images.amazon.com/images/P/1573229725.0...
# 58821  http://images.amazon.com/images/P/1586210661.0...
# 58822  http://images.amazon.com/images/P/1586212230.0...
#
#                                              Image-URL-M  \
# 0      http://images.amazon.com/images/P/002542730X.0...
# 1      http://images.amazon.com/images/P/0060930535.0...
# 2      http://images.amazon.com/images/P/0060934417.0...
# 3      http://images.amazon.com/images/P/0061009059.0...
# 4      http://images.amazon.com/images/P/006440188X.0...
# ...                                                  ...
# 58818  http://images.amazon.com/images/P/1400031354.0...
# 58819  http://images.amazon.com/images/P/1400031362.0...
# 58820  http://images.amazon.com/images/P/1573229725.0...
# 58821  http://images.amazon.com/images/P/1586210661.0...
# 58822  http://images.amazon.com/images/P/1586212230.0...
#
#                                              Image-URL-L
# 0      http://images.amazon.com/images/P/002542730X.0...
# 1      http://images.amazon.com/images/P/0060930535.0...
# 2      http://images.amazon.com/images/P/0060934417.0...
# 3      http://images.amazon.com/images/P/0061009059.0...
# 4      http://images.amazon.com/images/P/006440188X.0...
# ...                                                  ...
# 58818  http://images.amazon.com/images/P/1400031354.0...
# 58819  http://images.amazon.com/images/P/1400031362.0...
# 58820  http://images.amazon.com/images/P/1573229725.0...
# 58821  http://images.amazon.com/images/P/1586210661.0...
# 58822  http://images.amazon.com/images/P/1586212230.0...
#
# [58823 rows x 19 columns]

# %%
user_book_pt =  final_filtered_data.pivot_table(index= 'Book-Title_x', columns= 'User-ID', values= 'Book-Rating')

# %%
user_book_pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title_x
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             2977    3363    4017    \
# Book-Title_x
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             4385    6251    6323    \
# Book-Title_x
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     0.0     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             6543    ...  271705  \
# Book-Title_x                                                ...
# 1984                                                   NaN  ...    10.0
# 1st to Die: A Novel                                    9.0  ...     NaN
# 2nd Chance                                             0.0  ...     NaN
# 4 Blondes                                              NaN  ...     NaN
# A Bend in the Road                                     NaN  ...     NaN
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     NaN
# You Belong To Me                                       NaN  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN  ...     NaN
# Zoya                                                   NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# User-ID                                             273979  274004  274061  \
# Book-Title_x
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   0.0     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             274301  274308  275970  \
# Book-Title_x
# 1984                                                   NaN     NaN     0.0
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     0.0
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     0.0
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    8.0     NaN     NaN
#
# User-ID                                             277427  277639  278418
# Book-Title_x
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [707 rows x 815 columns]

# %% [markdown]
# - This is a sparse matrix

# %%
user_book_pt.fillna(value=0, inplace= True)

# %%
user_book_pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title_x
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             2977    3363    4017    \
# Book-Title_x
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             4385    6251    6323    \
# Book-Title_x
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             6543    ...  271705  \
# Book-Title_x                                                ...
# 1984                                                   0.0  ...    10.0
# 1st to Die: A Novel                                    9.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             273979  274004  274061  \
# Book-Title_x
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             274301  274308  275970  \
# Book-Title_x
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    8.0     0.0     0.0
#
# User-ID                                             277427  277639  278418
# Book-Title_x
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [707 rows x 815 columns]

# %% [markdown]
# ### **Cosine Similarity**

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def calculate_cosine_similarity(matrix):
    """
    Computes the cosine similarity between rows of a given matrix.

    Parameters:
    matrix (pd.DataFrame): The user-book interaction matrix.

    Returns:
    np.ndarray: A square matrix containing cosine similarity scores.
    """
    return cosine_similarity(matrix)

similarity_scores = calculate_cosine_similarity(matrix= user_book_pt)

# %%
similarity_scores
# Out:
# array([[1.        , 0.0999137 , 0.01189468, ..., 0.11799012, 0.07158663,
#         0.04205081],
#        [0.0999137 , 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01189468, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.11799012, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07158663, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04205081, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]], shape=(707, 707))

# %%
similarity_scores.shape
# Out:
# (707, 707)

# %%
def get_top_recommendations(book_title, similarity_matrix, book_titles, book_dataset, top_n=5):
    """
    Retrieves the top N book recommendations based on cosine similarity, along with Title, Author, and Image URL.

    Parameters:
    book_title (str): The title of the book for which recommendations are needed.
    similarity_matrix (np.ndarray): Precomputed cosine similarity matrix.
    book_titles (pd.Index): Index containing book titles corresponding to the matrix rows.
    book_dataset (pd.DataFrame): Dataset containing book information (Title, Author, Image URL).
    top_n (int, optional): Number of recommendations to return. Default is 5.

    Returns:
    list: A list of dictionaries containing Title, Author, and Image URL of the top N recommended books.
    """
    if book_title not in book_titles:
        return [{"message": "Book not found in dataset"}]

    book_idx = book_titles.get_loc(book_title)
    similarity_scores = list(enumerate(similarity_matrix[book_idx]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)

    top_recommendations = []
    
    # Collect top N books' Title, Author, and Image URL
    for i, _ in similarity_scores[1:top_n+1]:
        book_info = book_dataset.iloc[i]
        top_recommendations.append({
            "Title": book_info["Book-Title_x"],
            "Author": book_info["Book-Author_x"],
            "Image URL": book_info["Image-URL-M"]
        })
    
    return top_recommendations

# %%
get_top_recommendations(book_title= 'Harry Potter and the Prisoner of Azkaban (Book 3)' , similarity_matrix= similarity_scores, book_titles= user_book_pt.index,book_dataset=final_filtered_data)
# Out:
# [{'Title': 'The Gunslinger (The Dark Tower, Book 1)',
#   'Author': 'Stephen King',
#   'Image URL': 'http://images.amazon.com/images/P/0451160525.01.MZZZZZZZ.jpg'},
#  {'Title': 'The Tommyknockers',
#   'Author': 'Stephen King',
#   'Image URL': 'http://images.amazon.com/images/P/0451156609.01.MZZZZZZZ.jpg'},
#  {'Title': 'Pet Sematary',
#   'Author': 'Stephen King',
#   'Image URL': 'http://images.amazon.com/images/P/0451162072.01.MZZZZZZZ.jpg'},
#  {'Title': "Gerald's Game",
#   'Author': 'Stephen King',
#   'Image URL': 'http://images.amazon.com/images/P/0451176464.01.MZZZZZZZ.jpg'},
#  {'Title': 'Dolores Claiborne',
#   'Author': 'Stephen King',
#   'Image URL': 'http://images.amazon.com/images/P/0451177096.01.MZZZZZZZ.jpg'}]
