# %% [markdown]
# # **Top 60 Books based on popularity**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy import stats

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv("../artifacts/cleaned_data.csv",encoding='ISO-8859-1')

# %%
data.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6
#
#                                           Book-Title      Book-Author  \
# 0                               Flesh Tones: A Novel       M. J. Rose
# 1                                   Rites of Passage       Judith Rae
# 2                                       The Notebook  Nicholas Sparks
# 3                                     Help!: Level 1    Philip Prowse
# 4  The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather
#
#    Year-Of-Publication                   Publisher   Age     City  \
# 0               2002.0            Ballantine Books  35.0    tyler
# 1               2001.0                      Heinle  35.0  seattle
# 2               1996.0                Warner Books  16.0        h
# 3               1999.0  Cambridge University Press  16.0   rijeka
# 4               2001.0  Cambridge University Press  16.0   rijeka
#
#              State    Country     Age Group
# 0            texas        usa  Young Adults
# 1       washington        usa  Young Adults
# 2  new south wales  australia         Teens
# 3              NaN    croatia         Teens
# 4              NaN    croatia         Teens
